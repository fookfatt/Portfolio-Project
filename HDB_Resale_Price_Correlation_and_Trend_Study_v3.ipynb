# %% [markdown]
# # Objective
# ### To find correlation between HDB features and resale price
# ### scope : HDB resale transactions from Jan17 to Sep21
# ### Prediction : town,month of transaction,storey_range,floor_area_sqm,remaining lease

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Raw data obtain from https://data.gov.sg/dataset/resale-flat-prices
df = pd.read_csv(r'C:\Users\fookfatt91\Downloads\resale_flat_prices.csv')

# %%
#Let's look at the data
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %% [markdown]
# # Data Cleaning

# %%
#Let's see if there is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# month - 0.0%
# town - 0.0%
# flat_type - 0.0%
# block - 0.0%
# street_name - 0.0%
# storey_range - 0.0%
# floor_area_sqm - 0.0%
# flat_model - 0.0%
# lease_commence_date - 0.0%
# remaining_lease - 0.0%
# resale_price - 0.0%

# %%
# Check the data type of columns
df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# dtype: object

# %%
#change data type of columns
df['floor_area_sqm'] = df['floor_area_sqm'].astype('int64')
df['resale_price'] = df['resale_price'].astype('int64')
df['remaining_lease_year'] = df['remaining_lease'].astype('str').str[:2].astype('int64')
df['year'] = df['month'].astype('str').str[:4].astype('int64') #create new column ' year'

# %%
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0              44        Improved                 1979  61 years 04 months
# 1              67  New Generation                 1978  60 years 07 months
# 2              67  New Generation                 1980  62 years 05 months
# 3              68  New Generation                 1980   62 years 01 month
# 4              67  New Generation                 1980  62 years 05 months
#
#    resale_price  remaining_lease_year  year
# 0        232000                    61  2017
# 1        250000                    60  2017
# 2        262000                    62  2017
# 3        265000                    62  2017
# 4        265000                    62  2017

# %%
#take a look at the most expensive hdb sold
df.sort_values(by=['resale_price'],inplace=False,ascending=False).head(10)
# Out:
#           month             town  flat_type block    street_name storey_range  \
# 100046  2021-06  KALLANG/WHAMPOA     3 ROOM    39    JLN BAHAGIA     01 TO 03
# 78466   2020-09     CENTRAL AREA     5 ROOM    1B  CANTONMENT RD     43 TO 45
# 94955   2021-04           BISHAN     5 ROOM  273B   BISHAN ST 24     31 TO 33
# 83335   2020-11     CENTRAL AREA     5 ROOM    1A  CANTONMENT RD     49 TO 51
# 99233   2021-06           BISHAN     5 ROOM  273A   BISHAN ST 24     25 TO 27
# 100513  2021-06       QUEENSTOWN  EXECUTIVE   150    MEI LING ST     10 TO 12
# 68305   2020-03     CENTRAL AREA     5 ROOM    1B  CANTONMENT RD     40 TO 42
# 92503   2021-03           BISHAN     5 ROOM  273B   BISHAN ST 24     28 TO 30
# 85391   2020-12           BISHAN     5 ROOM  273B   BISHAN ST 24     25 TO 27
# 98314   2021-05       QUEENSTOWN     5 ROOM   18C     HOLLAND DR     34 TO 36
#
#         floor_area_sqm flat_model  lease_commence_date     remaining_lease  \
# 100046             210    Terrace                 1972   50 years 01 month
# 78466              107    Type S2                 2011  89 years 04 months
# 94955              120       DBSS                 2011  89 years 05 months
# 83335              105    Type S2                 2011  89 years 03 months
# 99233              120       DBSS                 2011  89 years 03 months
# 100513             148  Apartment                 1995  73 years 05 months
# 68305              107    Type S2                 2011  89 years 11 months
# 92503              120       DBSS                 2011  89 years 06 months
# 85391              120       DBSS                 2011  89 years 09 months
# 98314              117   Improved                 2012  90 years 05 months
#
#         resale_price  remaining_lease_year  year
# 100046       1268000                    50  2021
# 78466        1258000                    89  2020
# 94955        1250000                    89  2021
# 83335        1248000                    89  2020
# 99233        1238800                    89  2021
# 100513       1235000                    73  2021
# 68305        1232000                    89  2020
# 92503        1220000                    89  2021
# 85391        1218888                    89  2020
# 98314        1210000                    90  2021

# %%
#to look at all the data
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Finding correlation in data

# %%
#scatter plot with floor area vs resale price using matplotlib
plt.scatter(x=df['floor_area_sqm'],y=df['resale_price'])
plt.title('Floor Area,sqm vs Resale Price')
plt.xlabel('Floor Area,sqm')
plt.ylabel('Resale Price')
plt.show()

# %%
#plot with seaborn with correlation line
sns.regplot(data=df,x='floor_area_sqm',y='resale_price',scatter_kws={"color":"red"},line_kws={"color":"blue"})
plt.title('Floor Area,sqm vs Resale Price')
plt.show()

# %%
# 3 type of correlation methods pearson,kendall,spearman
df.corr(method='kendall')
# Out:
#                       floor_area_sqm  lease_commence_date  resale_price  \
# floor_area_sqm              1.000000             0.128726      0.509755
# lease_commence_date         0.128726             1.000000      0.275452
# resale_price                0.509755             0.275452      1.000000
# remaining_lease_year        0.125610             0.938523      0.265759
# year                        0.000402             0.090366      0.073501
#
#                       remaining_lease_year      year
# floor_area_sqm                    0.125610  0.000402
# lease_commence_date               0.938523  0.090366
# resale_price                      0.265759  0.073501
# remaining_lease_year              1.000000  0.004330
# year                              0.004330  1.000000

# %%
df.corr() #default = pearson
# Out:
#                       floor_area_sqm  lease_commence_date  resale_price  \
# floor_area_sqm              1.000000             0.162022      0.626038
# lease_commence_date         0.162022             1.000000      0.341099
# resale_price                0.626038             0.341099      1.000000
# remaining_lease_year        0.164474             0.994669      0.334598
# year                       -0.001058             0.119854      0.090840
#
#                       remaining_lease_year      year
# floor_area_sqm                    0.164474 -0.001058
# lease_commence_date               0.994669  0.119854
# resale_price                      0.334598  0.090840
# remaining_lease_year              1.000000  0.023878
# year                              0.023878  1.000000

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('HDB Features')
plt.ylabel('HDB Features')
plt.show()

# %%
#numerized features in other column to find correlation

df_numerized = df.copy()
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

# %%
df_numerized.head()
# Out:
#    month  town  flat_type  block  street_name  storey_range  floor_area_sqm  \
# 0      0     0          1   1064           12             3              44
# 1      0     0          2     35           15             0              67
# 2      0     0          2   1626           16             0              67
# 3      0     0          2   1238           12             1              68
# 4      0     0          2   1621           16             0              67
#
#    flat_model  lease_commence_date  remaining_lease  resale_price  \
# 0           4                 1979              201        232000
# 1          11                 1978              192        250000
# 2          11                 1980              214        262000
# 3          11                 1980              210        265000
# 4          11                 1980              214        265000
#
#    remaining_lease_year  year
# 0                    61  2017
# 1                    60  2017
# 2                    62  2017
# 3                    62  2017
# 4                    62  2017

# %%
df_numerized.sort_values(by='resale_price',ascending=False).head()
# Out:
#         month  town  flat_type  block  street_name  storey_range  \
# 100046     53    14          2   1032          218             0
# 78466      44     7          4    348          100            14
# 94955      51     2          4    616           54            10
# 83335      46     7          4    347          100            16
# 99233      53     2          4    615           54             8
#
#         floor_area_sqm  flat_model  lease_commence_date  remaining_lease  \
# 100046             210          17                 1972               66
# 78466              107          19                 2011              538
# 94955              120           3                 2011              539
# 83335              105          19                 2011              537
# 99233              120           3                 2011              537
#
#         resale_price  remaining_lease_year  year
# 100046       1268000                    50  2021
# 78466        1258000                    89  2020
# 94955        1250000                    89  2021
# 83335        1248000                    89  2020
# 99233        1238800                    89  2021

# %%
numerized_correlation_matrix = df_numerized.corr()
sns.heatmap(numerized_correlation_matrix,annot=True)
sns.set(rc={'figure.figsize':(12,10)})
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('HDB Features')
plt.ylabel('HDB Features')
plt.show()

# %%
#unstack for better visualization
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# month                 month                   1.000000
#                       town                    0.007824
#                       flat_type               0.010359
#                       block                   0.024129
#                       street_name             0.010974
#                       storey_range            0.012735
#                       floor_area_sqm         -0.000717
#                       flat_model             -0.024165
#                       lease_commence_date     0.121777
#                       remaining_lease         0.023562
#                       resale_price            0.088793
#                       remaining_lease_year    0.023568
#                       year                    0.978249
# town                  month                   0.007824
#                       town                    1.000000
#                       flat_type               0.106758
#                       block                   0.056029
#                       street_name             0.668028
#                       storey_range           -0.042244
#                       floor_area_sqm          0.095472
#                       flat_model             -0.086594
#                       lease_commence_date     0.233872
#                       remaining_lease         0.234922
#                       resale_price           -0.058779
#                       remaining_lease_year    0.234578
#                       year                    0.005947
# flat_type             month                   0.010359
#                       town                    0.106758
#                       flat_type               1.000000
#                       block                   0.055454
#                       street_name             0.068625
#                       storey_range            0.044476
#                       floor_area_sqm          0.950839
#                       flat_model             -0.340717
#                       lease_commence_date     0.227223
#                       remaining_lease         0.228875
#                       resale_price            0.637865
#                       remaining_lease_year    0.228749
#                       year                    0.009609
# block                 month                   0.024129
#                       town                    0.056029
#                       flat_type               0.055454
#                       block                   1.000000
#                       street_name             0.125500
#                       storey_range            0.002679
#                       floor_area_sqm          0.060568
#                       flat_model             -0.012094
#                       lease_commence_date     0.127207
#                       remaining_lease         0.126474
#                       resale_price           -0.019911
#                       remaining_lease_year    0.126306
#                       year                    0.023969
# street_name           month                   0.010974
#                       town                    0.668028
#                       flat_type               0.068625
#                       block                   0.125500
#                       street_name             1.000000
#                       storey_range           -0.068330
#                       floor_area_sqm          0.085909
#                       flat_model             -0.087849
#                       lease_commence_date     0.132258
#                       remaining_lease         0.133364
#                       resale_price           -0.031527
#                       remaining_lease_year    0.132978
#                       year                    0.009467
# storey_range          month                   0.012735
#                       town                   -0.042244
#                       flat_type               0.044476
#                       block                   0.002679
#                       street_name            -0.068330
#                       storey_range            1.000000
#                       floor_area_sqm         -0.002153
#                       flat_model             -0.051213
#                       lease_commence_date     0.279062
#                       remaining_lease         0.278809
#                       resale_price            0.370663
#                       remaining_lease_year    0.278896
#                       year                    0.013270
# floor_area_sqm        month                  -0.000717
#                       town                    0.095472
#                       flat_type               0.950839
#                       block                   0.060568
#                       street_name             0.085909
#                       storey_range           -0.002153
#                       floor_area_sqm          1.000000
#                       flat_model             -0.361429
#                       lease_commence_date     0.162022
#                       remaining_lease         0.164638
#                       resale_price            0.626038
#                       remaining_lease_year    0.164474
#                       year                   -0.001058
# flat_model            month                  -0.024165
#                       town                   -0.086594
#                       flat_type              -0.340717
#                       block                  -0.012094
#                       street_name            -0.087849
#                       storey_range           -0.051213
#                       floor_area_sqm         -0.361429
#                       flat_model              1.000000
#                       lease_commence_date    -0.124224
#                       remaining_lease        -0.124198
#                       resale_price           -0.253889
#                       remaining_lease_year   -0.124023
#                       year                   -0.022303
# lease_commence_date   month                   0.121777
#                       town                    0.233872
#                       flat_type               0.227223
#                       block                   0.127207
#                       street_name             0.132258
#                       storey_range            0.279062
#                       floor_area_sqm          0.162022
#                       flat_model             -0.124224
#                       lease_commence_date     1.000000
#                       remaining_lease         0.994912
#                       resale_price            0.341099
#                       remaining_lease_year    0.994669
#                       year                    0.119854
# remaining_lease       month                   0.023562
#                       town                    0.234922
#                       flat_type               0.228875
#                       block                   0.126474
#                       street_name             0.133364
#                       storey_range            0.278809
#                       floor_area_sqm          0.164638
#                       flat_model             -0.124198
#                       lease_commence_date     0.994912
#                       remaining_lease         1.000000
#                       resale_price            0.334605
#                       remaining_lease_year    0.999763
#                       year                    0.023799
# resale_price          month                   0.088793
#                       town                   -0.058779
#                       flat_type               0.637865
#                       block                  -0.019911
#                       street_name            -0.031527
#                       storey_range            0.370663
#                       floor_area_sqm          0.626038
#                       flat_model             -0.253889
#                       lease_commence_date     0.341099
#                       remaining_lease         0.334605
#                       resale_price            1.000000
#                       remaining_lease_year    0.334598
#                       year                    0.090840
# remaining_lease_year  month                   0.023568
#                       town                    0.234578
#                       flat_type               0.228749
#                       block                   0.126306
#                       street_name             0.132978
#                       storey_range            0.278896
#                       floor_area_sqm          0.164474
#                       flat_model             -0.124023
#                       lease_commence_date     0.994669
#                       remaining_lease         0.999763
#                       resale_price            0.334598
#                       remaining_lease_year    1.000000
#                       year                    0.023878
# year                  month                   0.978249
#                       town                    0.005947
#                       flat_type               0.009609
#                       block                   0.023969
#                       street_name             0.009467
#                       storey_range            0.013270
#                       floor_area_sqm         -0.001058
#                       flat_model             -0.022303
#                       lease_commence_date     0.119854
#                       remaining_lease         0.023799
#                       resale_price            0.090840
#                       remaining_lease_year    0.023878
#                       year                    1.000000
# dtype: float64

# %%
corr_pairs['resale_price'].sort_values(ascending=False)
# Out:
# resale_price            1.000000
# flat_type               0.637865
# floor_area_sqm          0.626038
# storey_range            0.370663
# lease_commence_date     0.341099
# remaining_lease         0.334605
# remaining_lease_year    0.334598
# year                    0.090840
# month                   0.088793
# block                  -0.019911
# street_name            -0.031527
# town                   -0.058779
# flat_model             -0.253889
# dtype: float64

# %% [markdown]
# # Conclusion
# ### HDB resale price is correlated to flat_type,floor_area_sqm,storey_range,lease_remaining

# %% [markdown]
# # Visualize resale hdb price trend

# %%
hdb = df.copy()

# %%
hdb.town.unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT PANJANG', 'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG',
#        'CLEMENTI', 'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'PASIR RIS', 'PUNGGOL',
#        'QUEENSTOWN', 'SEMBAWANG', 'SENGKANG', 'SERANGOON', 'TAMPINES',
#        'TOA PAYOH', 'WOODLANDS', 'YISHUN'], dtype=object)

# %%
hdb.flat_type.unique()
# Out:
# array(['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE', '1 ROOM',
#        'MULTI-GENERATION'], dtype=object)

# %% [markdown]
# # To plot a line graph to visualize recent increase in HDB prices
#
# <b>town available</b>
#
# ['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT PANJANG', 'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG',
#        'CLEMENTI', 'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'PASIR RIS', 'PUNGGOL',
#        'QUEENSTOWN', 'SEMBAWANG', 'SENGKANG', 'SERANGOON', 'TAMPINES',
#        'TOA PAYOH', 'WOODLANDS', 'YISHUN']
#
# <b>flat_type</b>
#
# ['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE', '1 ROOM','MULTI-GENERATION']

# %%
#to plot charts of median price from all town

plt.figure(figsize=[15,10],dpi=300)
for town in hdb.town.unique():
    town_filtered = hdb.loc[(hdb.town == town)][['month','resale_price']]
    townn_median = town_filtered.groupby('month').median()
    plt.plot(townn_median.index,townn_median.resale_price,marker='.',markersize = 10, linestyle='-',label=town)


plt.xticks(townn_median.index[::6],rotation=45)
plt.title('HDB Resale Median Price Trend by Town',fontsize='20',color='b')
plt.xlabel('Date',fontsize='15')
plt.ylabel('SGD',fontsize='15')
ax = plt.gca()
ax.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Visualize trend chart with filters
# ## town, room type, remaining lease

# %%
#filter
towns = ['SENGKANG','PUNGGOL','YISHUN','WOODLANDS']
rooms = ('4 ROOM')
min_lease_commense_date = 2004 #new variable to limit maximum age of the unit

plt.figure(figsize=[15,10],dpi=300)

for town in towns:
    town_filtered = hdb.loc[(hdb.town == town)&(hdb.flat_type == rooms)&(hdb.lease_commence_date > min_lease_commense_date)][['month','resale_price']]
    townn_median = town_filtered.groupby('month').median()
    plt.plot(townn_median.index,townn_median.resale_price,marker='.',markersize = 10, linestyle='-',label=town)

plt.xticks(townn_median.index[::6].tolist()+['2021-07'],rotation=45)
plt.title('HDB Resale Median Price Trend by Town ("4 ROOM")',fontsize='20',color='b')
plt.xlabel('Date',fontsize='15')
plt.ylabel('SGD',fontsize='15')
ax = plt.gca()
ax.grid(True)
plt.legend()
plt.show()
